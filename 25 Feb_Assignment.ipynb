# %%
'''
Consider the following code to answer further questions:
import pandas as pd
course_name = [‘Data Science’, ‘Machine Learning’, ‘Big Data’, ‘Data Engineer’]
duration = [2,3,6,4]
df = pd.DataFrame(data = {‘course_name’ : course_name, ‘duration’ : duration})

'''

# %%
#Q1. Write a code to print the data present in the second row of the dataframe, df.

# %%
import pandas as pd

# Assuming df is already created as per your provided code
course_name = ['Data Science', 'Machine Learning', 'Big Data', 'Data Engineer']
duration = [2, 3, 6, 4]
df = pd.DataFrame(data={'course_name': course_name, 'duration': duration})

# Printing data of the second row (index position 1)
second_row = df.iloc[1]
print(second_row)
# Out:
# course_name    Machine Learning
# duration                      3
# Name: 1, dtype: object

# %%
#Q2. What is the difference between the functions loc and iloc in pandas.DataFrame?

# %%
loc can locate any type of data but iloc locates only int values

# %%
#Q3. Reindex the given dataframe using a variable, reindex = [3,0,1,2] and store it in the variable, new_df then find the output for both new_df.loc[2] and new_df.iloc[2].
#Consider the below code to answer further questions:

# %%
import pandas as pd

# Assuming df is already created as per your provided code
course_name = ['Data Science', 'Machine Learning', 'Big Data', 'Data Engineer']
duration = [2, 3, 6, 4]
df = pd.DataFrame(data={'course_name': course_name, 'duration': duration})

# Define the new index order
reindex = [3, 0, 1, 2]

# Reindex the DataFrame df
new_df = df.reindex(reindex)

# Output of new_df.loc[2] and new_df.iloc[2]
print("Output of new_df.loc[2]:")
print(new_df.loc[2])    # Using label-based indexing

print("\nOutput of new_df.iloc[2]:")
print(new_df.iloc[2])   # Using integer-based indexing
# Out:
# Output of new_df.loc[2]:
# course_name    Big Data
# duration              6
# Name: 2, dtype: object
#
# Output of new_df.iloc[2]:
# course_name    Machine Learning
# duration                      3
# Name: 1, dtype: object

# %%
#Q4. Write a code to find the following statistical measurements for the above dataframe df1:
#(i) mean of each and every column present in the dataframe.
#(ii) standard deviation of column, ‘column_2’

# %%
import pandas as pd
import numpy as np

# Define column names and row indices
columns = ['column_1', 'column_2', 'column_3', 'column_4', 'column_5', 'column_6']
indices = [1, 2, 3, 4, 5, 6]

# Creating a DataFrame with random values
df1 = pd.DataFrame(np.random.rand(6, 6), columns=columns, index=indices)

# (i) Mean of each column
column_means = df1.mean()
print("Mean of each column:")
print(column_means)
print()  # Blank line for separation

# (ii) Standard deviation of column 'column_2'
std_dev_column_2 = df1['column_2'].std()
print("Standard deviation of column 'column_2':", std_dev_column_2)
# Out:
# Mean of each column:
# column_1    0.354654
# column_2    0.369519
# column_3    0.422695
# column_4    0.484371
# column_5    0.479558
# column_6    0.527069
# dtype: float64
#
# Standard deviation of column 'column_2': 0.2711367525119629

# %%
#Q5. Replace the data present in the second row of column, ‘column_2’ by a string variable then find the mean of column, column_2.
#If you are getting errors in executing it then explain why.
#Hint: To replace the data use df1.loc[] and equate this to string data of your choice.]

# %%
import pandas as pd
import numpy as np

# Define column names and row indices
columns = ['column_1', 'column_2', 'column_3', 'column_4', 'column_5', 'column_6']
indices = [1, 2, 3, 4, 5, 6]

# Creating a DataFrame with random values
df1 = pd.DataFrame(np.random.rand(6, 6), columns=columns, index=indices)

# Replace the data in the second row of 'column_2' with a string variable
df1.loc[2, 'column_2'] = 'Hello'  # Assuming 'Hello' is the string data of your choice

# Attempt to calculate the mean of 'column_2'
try:
    mean_column_2 = df1['column_2'].mean()
    print("Mean of column 'column_2':", mean_column_2)
except TypeError as e:
    print("Error occurred during mean calculation:", e)
# Out:
# Error occurred during mean calculation: unsupported operand type(s) for +: 'float' and 'str'

# %%
#Q6. What do you understand about the windows function in pandas and list the types of windows functions?

# %%
#The term "window functions" refers to a powerful feature for performing various operations on specified data windows within a Series or DataFrame. These functions operate on a set of data points defined by a window (or subset) of the data, enabling calculations like moving averages, cumulative sums, rolling statistics, and more.

# %%
#Q7. Write a code to print only the current month and year at the time of answering this question.
#[Hint: Use pandas.datetime function]

# %%
import pandas as pd

# Get current date and time
current_date = pd.Timestamp.now()

# Extract month and year
current_month = current_date.month
current_year = current_date.year

# Print current month and year
print(f"Current month: {current_month}")
print(f"Current year: {current_year}")
# Out:
# Current month: 5
# Current year: 2024

# %%
#Q8. Write a Python program that takes in two dates as input (in the format YYYY-MM-DD) and
#calculates the difference between them in days, hours, and minutes using Pandas time delta. The
#program should prompt the user to enter the dates and display the result.

# %%
import pandas as pd

def calculate_time_difference(date1, date2):
    try:
        # Convert input strings to pandas Timestamp objects
        date1 = pd.Timestamp(date1)
        date2 = pd.Timestamp(date2)

        # Calculate time difference using pandas Timedelta
        time_diff = date2 - date1

        # Extract days, hours, and minutes from the time difference
        days = time_diff.days
        hours = time_diff.seconds // 3600
        minutes = (time_diff.seconds % 3600) // 60

        return days, hours, minutes

    except ValueError:
        print("Error: Invalid date format. Please enter dates in YYYY-MM-DD format.")

if __name__ == "__main__":
    # Prompt the user to enter the two dates
    date1 = input("Enter the first date (YYYY-MM-DD): ")
    date2 = input("Enter the second date (YYYY-MM-DD): ")

    # Calculate time difference
    result = calculate_time_difference(date1, date2)

    if result is not None:
        days, hours, minutes = result
        print(f"Time difference: {days} days, {hours} hours, {minutes} minutes")
# Out:
# Enter the first date (YYYY-MM-DD):  2003-07-24
# Enter the second date (YYYY-MM-DD):  2007-10-23
# Time difference: 1552 days, 0 hours, 0 minutes

# %%
#Q9. Write a Python program that reads a CSV file containing categorical data and converts a specified
#column to a categorical data type. The program should prompt the user to enter the file path, column
#name, and category order, and then display the sorted data.

# %%
import pandas as pd

def convert_and_sort_categorical(csv_file, column_name, category_order):
    try:
        # Read the CSV file into a pandas DataFrame
        df = pd.read_csv(csv_file)

        # Convert the specified column to categorical data type with custom category order
        df[column_name] = pd.Categorical(df[column_name], categories=category_order, ordered=True)

        # Sort the DataFrame based on the specified categorical column
        sorted_df = df.sort_values(by=column_name)

        return sorted_df

    except FileNotFoundError:
        print(f"Error: File '{csv_file}' not found.")
    except KeyError:
        print(f"Error: Column '{column_name}' not found in the CSV file.")

if __name__ == "__main__":
    # Prompt the user to enter file path, column name, and category order
    csv_file = input("Enter the path to the CSV file: ")
    column_name = input("Enter the column name to convert to categorical data type: ")
    category_order_str = input("Enter the category order (comma-separated): ")

    # Split the category order string into a list
    category_order = [category.strip() for category in category_order_str.split(',')]

    # Convert and sort the categorical column
    sorted_dataframe = convert_and_sort_categorical(csv_file, column_name, category_order)

    if sorted_dataframe is not None:
        # Display the sorted DataFrame
        print("\nSorted DataFrame based on categorical column:")
        print(sorted_dataframe)
# Out:
# Enter the path to the CSV file:  csv_file.csv
# Enter the column name to convert to categorical data type:  application_process
# Enter the category order (comma-separated):  csv
# Sorted DataFrame based on categorical column:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# ...

# %%
#Q10. Write a Python program that reads a CSV file containing sales data for different products and
#visualizes the data using a stacked bar chart to show the sales of each product category over time. The
#program should prompt the user to enter the file path and display the chart.

# %%
import pandas as pd
import matplotlib.pyplot as plt

def visualize_sales_data(csv_file):
    try:
        # Read the CSV file into a pandas DataFrame
        df = pd.read_csv(csv_file)

        # Convert the 'Date' column to datetime format
        df['Date'] = pd.to_datetime(df['Date'])

        # Group the data by 'Date' and 'Product Category' and sum the sales
        grouped_df = df.groupby(['Date', 'Product Category'])['Sales'].sum().unstack()

        # Plotting a stacked bar chart
        grouped_df.plot(kind='bar', stacked=True, figsize=(10, 6))
        plt.title('Stacked Bar Chart of Sales by Product Category Over Time')
        plt.xlabel('Date')
        plt.ylabel('Sales')
        plt.xticks(rotation=45)
        plt.legend(title='Product Category', bbox_to_anchor=(1.05, 1), loc='upper left')

        # Display the chart
        plt.tight_layout()
        plt.show()

    except FileNotFoundError:
        print(f"Error: File '{csv_file}' not found.")

if __name__ == "__main__":
    # Prompt the user to enter the file path
    csv_file = input("Enter the path to the CSV file: ")

    # Visualize the sales data using a stacked bar chart
    visualize_sales_data(csv_file)

# %%
'''
Q11. You are given a CSV file containing student data that includes the student ID and their test score. Write
a Python program that reads the CSV file, calculates the mean, median, and mode of the test scores, and
displays the results in a table.
The program should do the followingM
I Prompt the user to enter the file path of the CSV file containing the student dataR
I Read the CSV file into a Pandas DataFrameR
I Calculate the mean, median, and mode of the test scores using Pandas toolsR
I Display the mean, median, and mode in a table.
Assume the CSV file contains the following columnsM
I Student ID: The ID of the studentR
I Test Score: The score of the student's test.
Example usage of the program:
Enter the file path of the CSV file containing the student data: student_data.csv
+-----------+--------+
| Statistic | Value |
+-----------+--------+
| Mean | 79.6 |
| Median | 82 |
| Mode | 85, 90 |
+-----------+--------+
Assume that the CSV file student_data.csv contains the following data:
Student ID,Test Score
1,85
2,90
3,80
4,75
5,85
6,82
7,78
8,85
9,90
10,85
The program should calculate the mean, median, and mode of the test scores and display the results
in a table.
'''

# %%
import pandas as pd
from tabulate import tabulate  # Import tabulate for table formatting

def calculate_statistics(csv_file):
    try:
        # Read the CSV file into a pandas DataFrame
        df = pd.read_csv(csv_file)

        # Calculate mean, median, and mode of the test scores
        mean_score = df['Test Score'].mean()
        median_score = df['Test Score'].median()
        mode_scores = df['Test Score'].mode()

        # Format mode_scores as a comma-separated string
        mode_str = ', '.join(map(str, mode_scores))

        # Create a dictionary to store the calculated statistics
        statistics = {
            'Statistic': ['Mean', 'Median', 'Mode'],
            'Value': [mean_score, median_score, mode_str]
        }

        # Display the statistics in a formatted table
        print(tabulate(statistics, headers='keys', tablefmt='fancy_grid'))

    except FileNotFoundError:
        print(f"Error: File '{csv_file}' not found.")

if __name__ == "__main__":
    # Prompt the user to enter the file path of the CSV file
    csv_file = input("Enter the file path of the CSV file containing the student data: ")

    # Calculate and display statistics for the test scores
    calculate_statistics(csv_file)
